# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

load_dotenv()

# %%
agent = Agent(name="Jokester", instructions = "You are a joke teller", model="")

# %%
result = Runner.run(agemt, "Tell a joke about Autonomous Ai Agents")
